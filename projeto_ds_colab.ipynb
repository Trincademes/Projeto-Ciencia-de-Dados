# %% [markdown]
# # 📊 Projeto Final: Análise de Dados com Python
# **Tema:** Análise de Desempenho de Alunos com Dados Simulados (`seaborn.tips`)
#
# Este projeto tem como objetivo aplicar técnicas estatísticas com base em dados simulados do ENEM, utilizando a linguagem Python e bibliotecas como Pandas, Seaborn, Matplotlib, Scipy e Numpy.

# %%
# Importação das bibliotecas necessárias
import pandas as pd                # Para manipulação de dados em formato tabular (DataFrame)
import seaborn as sns              # Para visualizações estatísticas elegantes
import matplotlib.pyplot as plt    # Para criação de gráficos
import numpy as np                 # Para operações numéricas e estatísticas
from scipy import stats            # Para realizar testes estatísticos (ex: normalidade)

# Carregamento do dataset de exemplo da biblioteca Seaborn
df = sns.load_dataset('tips')     # Dataset 'tips' simulado como se fossem dados de alunos

# Visualização das primeiras linhas do DataFrame
df.head()                         # Mostra as 5 primeiras linhas da tabela
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 🔍 Escalas de Medição
# - `total_bill`: Nota final (Escala de razão)
# - `sex`: Gênero do estudante (Escala nominal)
# - `day`: Dia da prova (Escala nominal)
# - `time`: Período da prova (Escala nominal)
# - `size`: Número de disciplinas (Escala de razão)

# %% [markdown]
# ## 📈 Medidas de Tendência Central

# %%
# Cálculo de medidas de tendência central
print("Média:", df['total_bill'].mean())     # Média da coluna 'total_bill' (nota final simulada)
print("Mediana:", df['total_bill'].median()) # Mediana das notas
print("Moda:", df['total_bill'].mode()[0])   # Moda das notas
# Out:
# Média: 19.78594262295082
# Mediana: 17.795
# Moda: 13.42

# %% [markdown]
# ## 📊 Medidas de Dispersão

# %%
# Cálculo de medidas de dispersão
print("Desvio padrão:", df['total_bill'].std())           # Desvio padrão
print("Variância:", df['total_bill'].var())              # Variância
print("Amplitude:", df['total_bill'].max() - df['total_bill'].min())  # Amplitude (máximo - mínimo)
# Out:
# Desvio padrão: 8.902411954856856
# Variância: 79.25293861397826
# Amplitude: 47.74

# %% [markdown]
# ## 📉 Visualizações

# %%
# Visualizações
sns.histplot(df['total_bill'], kde=True)  # Histograma com linha de densidade
plt.title('Distribuição das Notas (total_bill)')
plt.xlabel('Nota')
plt.ylabel('Frequência')
plt.show()

sns.boxplot(x='sex', y='total_bill', data=df) # Nome do eixo X e Y
plt.title('Notas por Gênero')
plt.show()

# %% [markdown]
# ## 🧪 Teste de Normalidade (Shapiro-Wilk)

# %%
# Teste de normalidade (Shapiro-Wilk)
stat, p = stats.shapiro(df['total_bill'])  # Aplica o teste à coluna 'total_bill'
print("Estatística:", stat)
print("p-valor:", p)
if p > 0.05:
    print("Distribuição normal")           # Interpretação do resultado
else:
    print("Distribuição não normal")
# Out:
# Estatística: 0.9197187941346584
# p-valor: 3.3245391868090786e-10
# Distribuição não normal

# %% [markdown]
# ## 🔗 Correlação entre Variáveis

# %%
# Correlação entre número de disciplinas (size) e nota (total_bill)
correlation = df[['total_bill', 'size']].corr()  # Matriz de correlação
print(correlation)

sns.scatterplot(x='size', y='total_bill', data=df)  # Gráfico de dispersão
plt.title('Correlação entre Número de Disciplinas e Notas')
plt.show()
# Out:
#             total_bill      size
# total_bill    1.000000  0.598315
# size          0.598315  1.000000

# %% [markdown]
# ## ✅ Conclusão
# O dataset `tips`, adaptado como simulação de desempenho escolar, permitiu a aplicação de técnicas estatísticas como tendência central, dispersão, testes de normalidade, correlação e visualizações. Observamos que as notas não seguem uma distribuição normal, e há uma correlação positiva entre o número de disciplinas e a nota final.
